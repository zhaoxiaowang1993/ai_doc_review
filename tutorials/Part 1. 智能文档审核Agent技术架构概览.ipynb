# %% [markdown]
# ## <font face="仿宋">课程说明：

# %% [markdown]
# - 体验课内容节选自[《2025大模型Agent智能体开发实战》(12月班)](https://ix9mq.xetslk.com/s/3qeesJ)完整版付费课程

# %% [markdown]
# &emsp;&emsp;体验课时间有限，若想深度学习大模型技术，欢迎大家报名由我主讲的[《2025大模型Agent智能体开发实战》(12月班)](https://ix9mq.xetslk.com/s/3qeesJ)

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/ac4f2a592e0453c3089da3643ee3404a.png" alt="ac4f2a592e0453c3089da3643ee3404a" style="zoom:33%;" />

# %% [markdown]
# **[《2025大模型Agent智能体开发实战》(12月班)](https://ix9mq.xetslk.com/s/3qeesJ)为【100+小时】体系大课，总共20大模块精讲精析，零基础直达大模型企业级应用！**

# %% [markdown]
# ### <center>课程完整介绍

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/202512111845933.png" alt="a92973f60f055b9109d991503fb7f000" style="zoom:50%;" />

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/6ee2fbee6b72608bee2888620fac1932.png" alt="6ee2fbee6b72608bee2888620fac1932" style="zoom:50%;" />

# %% [markdown]
# ### <center> 部分课程成果演示

# %%
from IPython.display import Video

# %% [markdown]
# - **Dify+DeepSeek搭建智能微信语音客服**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/2f1b47f42c65fd59e8d3a83e6cb9f13b_raw.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/2f1b47f42c65fd59e8d3a83e6cb9f13b_raw.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# - **Coze自动图文视频创作流程**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/Coze%E5%8A%A8%E6%80%81%E8%A7%86%E9%A2%91%E7%94%9F%E6%88%90%E5%AE%9E%E4%BE%8B.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/Coze%E5%8A%A8%E6%80%81%E8%A7%86%E9%A2%91%E7%94%9F%E6%88%90%E5%AE%9E%E4%BE%8B.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# - **可视化数据分析Multi-Agent**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/%E5%8F%AF%E8%A7%86%E5%8C%96%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90Multi-Agent%E6%95%88%E6%9E%9C%E6%BC%94%E7%A4%BA%E6%95%88%E6%9E%9C.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/%E5%8F%AF%E8%A7%86%E5%8C%96%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90Multi-Agent%E6%95%88%E6%9E%9C%E6%BC%94%E7%A4%BA%E6%95%88%E6%9E%9C.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# - **高效微调全自动数据集创建**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/easy_daset_yanshi.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/easy_daset_yanshi.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# - **MateGen Pro 项目功能演示**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/MG%E6%BC%94%E7%A4%BA%E8%A7%86%E9%A2%91.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/MG%E6%BC%94%E7%A4%BA%E8%A7%86%E9%A2%91.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# - **智能客服项目展示**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/%E6%99%BA%E8%83%BD%E5%AE%A2%E6%9C%8D%E6%A1%88%E4%BE%8B%E8%A7%86%E9%A2%91.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/%E6%99%BA%E8%83%BD%E5%AE%A2%E6%9C%8D%E6%A1%88%E4%BE%8B%E8%A7%86%E9%A2%91.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# - **GraphRAG+多模态文档检索**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/7%E6%9C%8817%E6%97%A5%281%29%20%E8%BF%9B%E5%BA%A6%E6%9D%A1.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/7%E6%9C%8817%E6%97%A5%281%29%20%E8%BF%9B%E5%BA%A6%E6%9D%A1.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# 此外，若是对大模型底层原理感兴趣，也欢迎报名由我和菜菜老师共同主讲的[《2025大模型原理与实战课程》(秋季班)](https://ix9mq.xetslk.com/s/16asFh)

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/a9c8776df826a9ee8e9fb8e31c72b180.png" alt="a9c8776df826a9ee8e9fb8e31c72b180" style="zoom: 20%;" />

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/202512161931288.png" alt="dffbf01608bee33700732e009f9580c2" style="zoom:50%;" />

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/202512102014091.jpg" alt="282126fbd48fc7124eaaa5ce9761443e" style="zoom:45%;" />

# %% [markdown]
# **<span style="color:red;">详细信息扫码添加助教，回复“大模型”，即可领取课程大纲&查看课程详情👇</span>**

# %% [markdown]
# <center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171342119.png" style="zoom:70%;" />

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/202512091834833.png" alt="1b29bf01197a27bbb67de0c7003311e2" style="zoom:50%;" />

# %% [markdown]
# ---

# %% [markdown]
# # <center>Part 1. 智能文档审核Agent技术架构概览</center>
#
# ## <center>从技术选型到产品落地</font>

# %%
from IPython.display import Video

Video("https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171715947.mp4", width=1500, height=400)
# Out:
# <video src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171715947.mp4" controls  width="1500"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# &emsp;&emsp;<font color='red'>**本期公开课，我们将深入探索基于大语言模型的文档审核Agent技术方案。**</font>

# %% [markdown]
# - **文档审核类Agent系统功能速览**

# %% [markdown]
# &emsp;&emsp;核心功能一：支持.pdf，同时也支持快速扩展.doc、.docx、.ppt、.pptx、.png、.jpg、.jpeg等多种格式的文档在线上传与解析；
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171217557.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;核心功能二：可以针对结构化数据高精准度提取文本内容和位置信息，并进行高亮展示
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171724269.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;核心功能三：支持人机交互功能，可以由人工随时介入审核流程，并给出审核意见
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171727069.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;核心功能四：针对单个文件支持在线自定义规则，并实时发起重新审查，并实现持久化数据管理
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171729773.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;当然，该智能文档审核系统的研发我们需要应用到核心的Agent开发技术，主要由如下技术模块组成：
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171741927.png" width=80%></div>

# %% [markdown]
# # 一、文档审核类AI成熟落地产品介绍

# %% [markdown]
# &emsp;&emsp;首先看一组数据，如下论文中是对法律大模型与传统法律合同审查员、初级律师和法律流程外包商进行了开创性的比较，并深入剖析了大模型在合同审查的准确性、速度和成本效益方面是否能够超越人类。而最终的实验结果表明，先进的大模型在确定法律问题方面的准确性能够达到甚至超过人类。在速度方面，大模型只需几秒钟即可完成审查，远超人类所需的数小时。在成本方面，大模型的运行成本仅为传统方法的几分之一，成本降低了惊人的 99.97%。
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202511171625258.png" width=70%></div>
#
# > 论文地址：https://arxiv.org/pdf/2401.16212

# %% [markdown]
# &emsp;&emsp;随着大模型能力的提升，将其作为智能代理用于专业文档的合规性审核已经从理论变为现实，并且在多个行业中展现出了惊人的效率提升。
#
# &emsp;&emsp;<font color=red>**文档合规审核指的是根据法律法规、行业规范或企业内部规则，对各种专业文件进行内容和格式上的检查，以发现潜在的违规或缺陷之处。典型场景包括：合同文档的法律合规审核、财务票据的规范校验、以及标书、公文等特定格式文件的规则符合性检查**。</font>以下是我们国内已经落地的在文档审核类产品中大模型的落地场景：

# %% [markdown]
# - **阿里的通义法睿**：可以用于快速识别合同潜在风险，并提供专业的风险评估和修改建议。 体验地址：https://tongyi.aliyun.com/farui/review

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202511171645949.png" width=70%></div>

# %% [markdown]
# - **百度的财务、医疗、教育票据OCR识别及自动审查** ： https://ai.baidu.com/tech/ocr_receipts/vat_invoice

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202511171631930.png" width=70%></div>

# %% [markdown]
# - **语核科技的数字员工（文档审查方向）：https://langcore.cn/zh**

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202511171634735.png" width=70%></div>

# %% [markdown]
# &emsp;&emsp;关于上述审核系统的复现，在我的往期公开课中有非常详细的说明：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171209858.png" width=70%></div>

# %% [markdown]
# &emsp;&emsp;项目的前后端源码已经上传到百度网盘中，大家可以扫码免费下载：
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202511281211724.png" width=80%></div>

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171342119.png" width=30%></div>

# %% [markdown]
# &emsp;&emsp;诸如此类的文档合规审核Agent是指基于大语言模型构建的智能代理系统，能够根据法律法规、行业规范或企业内部规则，自动对专业文件进行内容和格式上的检查，发现潜在的违规或缺陷之处，从而避免人工审核耗时耗力等诸多问题。同时也正是在这样的需求痛点下，文档审核类Agent目前主要应用在如下经典场景下：
#
# <style>
# .center
# {
#   width: auto;
#   display: table;
#   margin-left: auto;
#   margin-right: auto;
# }
# </style>
#
# <p align="center"><font face="黑体" size=4>文档审核Agent核心应用场景</font></p>
# <div class="center">
#
# | 场景类型 | 审核内容 | 核心价值 | 难度等级 |
# |---------|---------|---------|---------|
# | **法务合同审核** | 必要条款检查、法律风险识别、措辞合规性 | 降低法律风险、提升审核效率 | ⭐⭐⭐⭐⭐ |
# | **财务票据校验** | 发票真伪、金额计算、政策合规 | 减少财务错误、加速报销流程 | ⭐⭐⭐⭐ |
# | **标书公文审核** | 格式规范、必备内容、章节完整性 | 提高中标率、确保公文质量 | ⭐⭐⭐ |
#
# </div>

# %% [markdown]
# &emsp;&emsp;之所以能够实现上述复杂工作流程的原因在于<font color=red>**基于大模型构建而成的Agent具备自主决策和工具调用能力**</font>：
#
# 1. **自主推理**：不只是执行预设规则，而是能理解文档语义、推理条款间的逻辑关系
# 2. **工具编排**：可以主动调用外部工具（如计算器、数据库查询、API接口）来辅助判断
# 3. **知识检索**：能从知识库中检索相关法规、案例，基于证据给出审核意见
# 4. **链式思考**：像人类专家一样，分步骤、有逻辑地完成复杂审核任务
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202511281052021.png" width=70%></div>

# %% [markdown]
# > 论文地址：https://arxiv.org/pdf/2501.09136

# %% [markdown]
# &emsp;&emsp;在合同、票据/收据、长篇公文等场景中，“大模型 + 工具调用 + 外部知识检索 + 规划/反思（Agentic模式）” 能把抽取、核对与基于证据的判断串成多步流程，用于自动化或半自动的合规审核。法务合同有 CUAD 这一权威标注集支撑条款级审核可行性；多模态文档 AI（如 LayoutLMv3 / LayoutLLM）显著提升了票据/表单/PDF 的结构化与问答能力；而 Agentic RAG/RA-LLM 则把检索、工具使用与多步推理纳入可控工作流。

# %% [markdown]
# &emsp;&emsp;同样，针对上图中的文档审核类的实现方案，如果进一步拆分则可以拆解为如下三大核心技术模块：
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202511181424904.png" width=90%></div>

# %% [markdown]
# &emsp;&emsp;而如果再进一步拆解，则如下图所示：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202511181443709.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;其中：
#
# * **解析与结构化**：主流 Document AI 都把 OCR/布局/键值对/表格抽取到统一 JSON，并附带**置信度与坐标**，便于后续规则与证据回链。
# * **规则与知识**：企业审核离不开**可配置规则引擎**（版本化/审计）与**RAG**（把法规与制度做成可检索、可引用的知识源），并通过**混合检索+重排序**提升命中与可溯源性。
# * **Agent 编排**：用 LangGraph/LangChain 等做**计划-工具调用-记忆-长流程编排**，并把**人类在环**作为低置信度的兜底环节。
# * **评估与治理**：上线后需要字段级与 RAG 两路评估、Tracing/监控，以及 PII/审计合规治理，形成持续改进闭环。

# %% [markdown]
# &emsp;&emsp;所以一个相对比较健全的文档审核类Agent的实现，不仅需要我们掌握 Agent 及 RAG 的底层技术原理，还需要我们掌握多模态大模型、多 Agent 协作、Prompt 工程、Agent 编排等技术。综合起来是相对较难的落地场景。

# %% [markdown]
# &emsp;&emsp;此外，对于文档的精准解析是文档审核类Agent落地的关键，也主要分为`OCR`和`VLM` 两条实现链路，通过传统 OCR +规则的方法逐步转到现在基于 VLM-based 方法的革新，可以在不同场景下发挥各自的优势。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171748193.png" width=70%></div>

# %% [markdown]
# > 技术综述地址：https://www.firstsource.com/insights/whitepapers/document-processing-with-vlm

# %% [markdown]
# &emsp;&emsp;我们本次项目使用的：`MinerU`是一个非常典型的基于管道的解决方案 (Pipeline-based solution) ，并且是一个开源文档解析项目，一共四个核心组件，通过`Pipeline`的设计无缝衔接，实现比较高效、准确的文档解析。如下图所示：（下图来源官方论文：https://arxiv.org/pdf/2409.18839v1）

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503271440433.png" width=70%></div>

# %% [markdown]
# &emsp;&emsp;`MinerU`的主要工作流程分为以下几个阶段：
#
# 1. **输入**：接收`PDF` 格式文本，可以是简单的纯文本，也可以是包含双列文本、公式、表格或图等多模态`PDF`文件;
# 2. **文档预处理（Document Preprocessing）**：检查语言、页面大小、文件是否被扫描以及加密状态；
# 3. **内容解析（Content Parsing）**：
#     - 局分析：区分文本、表格和图像。
#     - 公式检​​测和识别：识别公式类型（内联、显示或忽略）并将其转换为 `LaTeX` 格式。
#     - 表格识别：以 `HTML/LaTeX` 格式输出表格。
#     - OCR：对扫描的 `PDF` 执行文本识别。
# 4. **内容后处理（Content Post-processing）**：修复文档解析后可能出现的问题。比如解决文本、图像、表格和公式块之间的重叠，并根据人类阅读模式重新排序内容，确保最终输出遵循自然的阅读顺序。
# 5. **格式转换（Format Conversion）**：以 `Markdown` 或 `JSON` 格式生成输出。
# 6. **输出（Output）**：高质量、结构良好的解析文档。

# %% [markdown]
# &emsp;&emsp;目前在`Github` 上，`MinerU` 的`Star` 数为`48.2K`，`Fork` 数为`4K`，拥有非常良好的社区支持和活跃的贡献者，且一直处于`active development`状态。

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202511071014588.png" width=80%></div>

# %% [markdown]
# &emsp;&emsp;`MinerU` 提供了在线`Demo` 页面，我们可以直接线进行测试。试用地址：https://opendatalab.com/OpenSourceTools/Extractor/PDF/

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503271502432.png" width=70%></div>

# %% [markdown]
# &emsp;&emsp;同时，`MinerU` 项目于`2024年07月05日`首次开源，底层主要是集成 `PDF-Extract-Kit` 开源项目做`PDF`的内容提取，`PDF-Extract-Kit`同样是一个开源项目：https://github.com/opendatalab/PDF-Extract-Kit

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202503251117693.png" width=70%></div>

# %% [markdown]
# &emsp;&emsp;`PDF-Extract-Kit`这个项目主要针对的是`PDF`文档的内容提取，通过集成众多`SOTA`模型对`PDF`文件实现高质量的内容提取，其中应用到的模型主要包括：

# %% [markdown]
# <style>
# .center
# {
#   width: auto;
#   display: table;
#   margin-left: auto;
#   margin-right: auto;
# }
# </style>
#
# <p align="center"><font face="黑体" size=4>PDF-Extract-Kit 应用的模型类型</font></p>
# <div class="center">
#
#
# | 模型类型       | 模型名称         | GitHub 链接                                                                 | 模型下载链接                                                       | 任务描述                                           |
# |----------------|------------------|---------------------------------------------------------------------------|-------------------------------------------------------------------|----------------------------------------------------|
# | 布局检测模型   | LayoutLMv3 / DocLayout-YOLO | [GitHub](https://github.com/microsoft/unilm/tree/master/layoutlmv3) / [GitHub](https://github.com/opendatalab/DocLayout-YOLO) | [模型下载](https://huggingface.co/microsoft/layoutlmv3-base-chinese) / [模型下载](https://huggingface.co/juliozhao/DocLayout-YOLO-DocStructBench/tree/main) | 定位文档中不同元素位置：包含图像、表格、文本、标题、公式等 |
# | 公式检测模型   | YOLO             | [GitHub](https://github.com/ultralytics/ultralytics)                     | [模型下载](https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt) | 定位文档中公式位置：包含行内公式和行间公式         |
# | 公式识别模型   | UniMERNet        | [GitHub](https://github.com/opendatalab/UniMERNet)                       | [模型下载](https://huggingface.co/wanderkid/unimernet_base)      | 识别公式图像为latex源码                             |
# | 表格识别模型   | StructEqTable    | [GitHub](https://github.com/Alpha-Innovator/StructEqTable-Deploy?tab=readme-ov-file) | [模型下载](https://huggingface.co/U4R/StructTable-InternVL2-1B/tree/main) | 识别表格图像为对应源码（Latex/HTML/Markdown）     |
# | OCR模型        | PaddleOCR        | [GitHub](https://github.com/PaddlePaddle/PaddleOCR)                      | [模型下载](https://paddlepaddle.github.io/PaddleX/latest/module_usage/tutorials/ocr_modules/text_detection.html)                                                                  | 提取图像中的文本内容（包括定位和识别）             |
# </div>

# %% [markdown]
# &emsp;&emsp;`MinerU` 既支持Pipeline，也支持 VLM 模式：

# %% [markdown]
# <div align="center">
#     <img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202508061340184.png" alt="MinerU 配置参考" width="800">
# </div>

# %% [markdown]
# &emsp;&emsp;`VLM-Transformer`则是直接利用`transformers`库中的`Vision-Language`模型处理图像+文本的多模态输入，其流程如下：
#
# <div align="center">
#     <img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202508061356866.png" alt="MinerU 配置参考" width="800">
# </div>
#
# &emsp;&emsp;而`VLM-Sglang`后端则是利用`sglang`高性能推理引擎，优化了GPU加速及分布式部署的基础上同时支持实时流式输出，其流程如下：
#
# <div align="center">
#     <img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202508061356864.png" alt="MinerU 配置参考" width="800">
# </div>

# %% [markdown]
# &emsp;&emsp;其中对于VLM模式：

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202511181655278.png" width=80%></div>

# %% [markdown]
# - Pipeline模式：
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202510211239047.png" width=70%></div>

# %% [markdown]
# # 二、智能文档审核Agent本地部署

# %% [markdown]
# &emsp;&emsp;首先，大家可以在百度网盘中下载到完整的项目源码：
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202511071654511.png" width=70%></div>

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171342119.png" width=30%></div>

# %% [markdown]
# &emsp;&emsp;下载后上传到服务器，并解压项目包：
#
# ```bash
#     unzip ai-document-review.zip
#     cd ai-document-review
# ```

# %% [markdown]
# &emsp;&emsp;我给大家做了一键安装的脚本，可以快速部署项目运行的前后端依赖及服务启动，首先：

# %% [markdown]
# ```bash
#     chmod +x install.sh start.sh stop.sh
# ```
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171724263.png" width=90%></div>

# %% [markdown]
# &emsp;&emsp;然后执行安装脚本：
#
# ```bash
#     ./install.sh
# ```
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171724264.png" width=90%></div>

# %% [markdown]
# &emsp;&emsp;安装完成后，在启动前配置环境变量：
#
# 1. **DeepSeek API Key**：访问 [DeepSeek 开放平台](https://platform.deepseek.com/)，注册账号后获取 API Key；
# 2. **MinerU API Key**：访问 [MinerU 官网](https://mineru.net/)，需要先进行API申请，然后创建 Token 即可。
#
# ```
#     vim .env
# ```
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171724265.png" width=90%></div>

# %% [markdown]
# &emsp;&emsp;配置完成后，执行启动脚本：
#
# ```bash
#     ./start.sh
# ```
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171724266.png" width=90%></div>

# %% [markdown]
# &emsp;&emsp;启动完成后，在浏览器中打开: **http://localhost:5173**
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171724267.png" width=90%></div>
#
#
# &emsp;&emsp;同时也可以查看到 API 文档: **http://localhost:8000/docs**
#
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202512171724268.png" width=90%></div>

# %% [markdown]
# &emsp;&emsp;至此，我们就完成了智能文档审核Agent的本地部署，大家便可以开始上传文档进行审核功能的应用了。
